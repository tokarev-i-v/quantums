# %%
from qiskit import QuantumCircuit, QuantumRegister, Aer, execute

# %%
input_bit = QuantumRegister(1, 'input')
output_bit = QuantumRegister(1, 'output')
garbage_bit = QuantumRegister(1, 'garbate')

Uf = QuantumCircuit(input_bit, output_bit, garbage_bit)
Uf.cx(input_bit[0], output_bit[0])

Uf.draw(output='mpl', justify='none')

# %%
Vf = QuantumCircuit(input_bit, output_bit, garbage_bit)
Vf.cx(input_bit[0], garbage_bit[0])
Vf.cx(input_bit[0], output_bit[0])

Vf.draw(output='mpl', justify='none')

# %%
qc = Uf + Vf.inverse()
qc.draw(output='mpl', justify='none')

# %%
final_output_bit = QuantumRegister(1, 'final_output')
copy = QuantumCircuit(output_bit, final_output_bit)
copy.cx(output_bit, final_output_bit)

copy.draw(output='mpl', justify='none')

# %%
(Vf.inverse() + copy + Vf).draw(ouput='mpl', justify='none')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c8bbfa70453e> in <module>
# ----> 1 (Vf.inverse() + copy + Vf).draw(ouput='mpl', justify='none')
#
# TypeError: draw() got an unexpected keyword argument 'ouput'

# %%
import gym
import numpy as np

# %%
a = gym.spaces.Box(low=np.array([-1, -1, -1, -1]), high=np.array([np.inf, np.inf, np.inf, np.inf]), dtype = np.float32)
# Out:
# /home/sheff/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
a.sample()
# Out:
# array([0.45601937, 2.946544  , 1.6662792 , 2.1410098 ], dtype=float32)
