# %%
# !pip install -U qiskit
# Out:
# Collecting qiskit
#   Downloading qiskit-0.22.0.tar.gz (4.1 kB)
# Collecting qiskit-terra==0.15.2
#   Downloading qiskit_terra-0.15.2-cp37-cp37m-manylinux2010_x86_64.whl (8.3 MB)
#      |████████████████████████████████| 8.3 MB 4.3 MB/s eta 0:00:01
# Collecting qiskit-aer==0.6.1
#   Downloading qiskit_aer-0.6.1-cp37-cp37m-manylinux2010_x86_64.whl (16.5 MB)
#      |████████████████████████████████| 16.5 MB 6.2 MB/s eta 0:00:01
# Collecting qiskit-ibmq-provider==0.10.0
#   Downloading qiskit_ibmq_provider-0.10.0-py3-none-any.whl (194 kB)
#      |████████████████████████████████| 194 kB 11.2 MB/s eta 0:00:01
# Collecting qiskit-ignis==0.4.0
#   Downloading qiskit_ignis-0.4.0-py3-none-any.whl (172 kB)
#      |████████████████████████████████| 172 kB 12.4 MB/s eta 0:00:01
# Collecting qiskit-aqua==0.7.5
#   Downloading qiskit_aqua-0.7.5-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 10.6 MB/s eta 0:00:01
# Collecting retworkx>=0.4.0
#   Downloading retworkx-0.5.0-cp37-cp37m-manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 11.2 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: scipy>=1.4 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-terra==0.15.2->qiskit) (1.4.1)
# Requirement already satisfied, skipping upgrade: python-constraint>=1.4 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-terra==0.15.2->qiskit) (1.4.0)
# Requirement already satisfied, skipping upgrade: dill>=0.3 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-terra==0.15.2->qiskit) (0.3.2)
# Requirement already satisfied, skipping upgrade: fastjsonschema>=2.10 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-terra==0.15.2->qiskit) (2.14.4)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.8.0 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-terra==0.15.2->qiskit) (2.8.1)
# Requirement already satisfied, skipping upgrade: ply>=3.10 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-terra==0.15.2->qiskit) (3.11)
# Requirement already satisfied, skipping upgrade: networkx>=2.2; python_version > "3.5" in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-terra==0.15.2->qiskit) (2.4)
# Requirement already satisfied, skipping upgrade: sympy>=1.3 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-terra==0.15.2->qiskit) (1.5.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.17 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-terra==0.15.2->qiskit) (1.18.0)
# Requirement already satisfied, skipping upgrade: psutil>=5 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-terra==0.15.2->qiskit) (5.6.7)
# Requirement already satisfied, skipping upgrade: jsonschema>=2.6 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-terra==0.15.2->qiskit) (3.2.0)
# Requirement already satisfied, skipping upgrade: cython>=0.27.1 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-aer==0.6.1->qiskit) (0.29.14)
# Requirement already satisfied, skipping upgrade: pybind11>=2.4 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-aer==0.6.1->qiskit) (2.5.0)
# Requirement already satisfied, skipping upgrade: urllib3>=1.21.1 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-ibmq-provider==0.10.0->qiskit) (1.25.8)
# Collecting websockets>=8; python_version > "3.6"
#   Using cached websockets-8.1-cp37-cp37m-manylinux2010_x86_64.whl (79 kB)
# Requirement already satisfied, skipping upgrade: requests>=2.19 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-ibmq-provider==0.10.0->qiskit) (2.22.0)
# Requirement already satisfied, skipping upgrade: nest-asyncio!=1.1.0,>=1.0.0 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-ibmq-provider==0.10.0->qiskit) (1.3.3)
# Requirement already satisfied, skipping upgrade: requests-ntlm>=1.1.0 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-ibmq-provider==0.10.0->qiskit) (1.1.0)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.17 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-ignis==0.4.0->qiskit) (0.23.1)
# Requirement already satisfied, skipping upgrade: setuptools>=40.1.0 in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-ignis==0.4.0->qiskit) (45.2.0.post20200210)
# Requirement already satisfied, skipping upgrade: dlx in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-aqua==0.7.5->qiskit) (1.0.4)
# Requirement already satisfied, skipping upgrade: h5py in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-aqua==0.7.5->qiskit) (2.10.0)
# Collecting yfinance
#   Downloading yfinance-0.1.55.tar.gz (23 kB)
# Requirement already satisfied, skipping upgrade: fastdtw in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-aqua==0.7.5->qiskit) (0.3.4)
# Requirement already satisfied, skipping upgrade: quandl in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-aqua==0.7.5->qiskit) (3.5.0)
# Requirement already satisfied, skipping upgrade: pandas in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-aqua==0.7.5->qiskit) (0.25.3)
# Requirement already satisfied, skipping upgrade: docplex in /home/sheff/anaconda3/lib/python3.7/site-packages (from qiskit-aqua==0.7.5->qiskit) (2.14.186)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /home/sheff/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.15.2->qiskit) (1.14.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /home/sheff/anaconda3/lib/python3.7/site-packages (from networkx>=2.2; python_version > "3.5"->qiskit-terra==0.15.2->qiskit) (4.4.1)
# Requirement already satisfied, skipping upgrade: mpmath>=0.19 in /home/sheff/anaconda3/lib/python3.7/site-packages (from sympy>=1.3->qiskit-terra==0.15.2->qiskit) (1.1.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /home/sheff/anaconda3/lib/python3.7/site-packages (from jsonschema>=2.6->qiskit-terra==0.15.2->qiskit) (1.5.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /home/sheff/anaconda3/lib/python3.7/site-packages (from jsonschema>=2.6->qiskit-terra==0.15.2->qiskit) (19.3.0)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in /home/sheff/anaconda3/lib/python3.7/site-packages (from jsonschema>=2.6->qiskit-terra==0.15.2->qiskit) (0.15.7)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /home/sheff/anaconda3/lib/python3.7/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.10.0->qiskit) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/sheff/anaconda3/lib/python3.7/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.10.0->qiskit) (2019.11.28)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /home/sheff/anaconda3/lib/python3.7/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.10.0->qiskit) (3.0.4)
# Requirement already satisfied, skipping upgrade: ntlm-auth>=1.0.2 in /home/sheff/anaconda3/lib/python3.7/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.10.0->qiskit) (1.5.0)
# Requirement already satisfied, skipping upgrade: cryptography>=1.3 in /home/sheff/anaconda3/lib/python3.7/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.10.0->qiskit) (2.8)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /home/sheff/anaconda3/lib/python3.7/site-packages (from scikit-learn>=0.17->qiskit-ignis==0.4.0->qiskit) (2.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /home/sheff/anaconda3/lib/python3.7/site-packages (from scikit-learn>=0.17->qiskit-ignis==0.4.0->qiskit) (0.14.1)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.9.tar.gz (8.1 kB)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.5.2-cp37-cp37m-manylinux1_x86_64.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 11.1 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: inflection>=0.3.1 in /home/sheff/anaconda3/lib/python3.7/site-packages (from quandl->qiskit-aqua==0.7.5->qiskit) (0.5.0)
# Requirement already satisfied, skipping upgrade: more-itertools in /home/sheff/anaconda3/lib/python3.7/site-packages (from quandl->qiskit-aqua==0.7.5->qiskit) (8.2.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/sheff/anaconda3/lib/python3.7/site-packages (from pandas->qiskit-aqua==0.7.5->qiskit) (2019.1)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /home/sheff/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema>=2.6->qiskit-terra==0.15.2->qiskit) (2.2.0)
# Requirement already satisfied, skipping upgrade: cffi!=1.11.3,>=1.8 in /home/sheff/anaconda3/lib/python3.7/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.10.0->qiskit) (1.14.0)
# Requirement already satisfied, skipping upgrade: pycparser in /home/sheff/anaconda3/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.10.0->qiskit) (2.19)
# Building wheels for collected packages: qiskit, yfinance, multitasking
#   Building wheel for qiskit (setup.py) ... done
#   Created wheel for qiskit: filename=qiskit-0.22.0-py3-none-any.whl size=2870 sha256=72f426bd5bb059113307511e4c2038a8aaf972d43637d56d7937dde46ace2f57
#   Stored in directory: /home/sheff/.cache/pip/wheels/eb/69/07/d0871c38574965a1a6b5d2320986a188e6ca502f889fc78668
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22616 sha256=feafe712fa7e93ae7ced721df6e5827d4724f7def7a7adfc2962ba2eeb4f3d31
#   Stored in directory: /home/sheff/.cache/pip/wheels/aa/8a/36/59ed4f6fbcb6100967618eeb0696046bf9777a41ac2ff1f9b9
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8366 sha256=60b62937dd4ab4f9f2e84976c7b35054d2609a46c98977f5f4a4c54999947a5c
#   Stored in directory: /home/sheff/.cache/pip/wheels/ae/25/47/4d68431a7ec1b6c4b5233365934b74c1d4e665bf5f968d363a
# Successfully built qiskit yfinance multitasking
# ERROR: deeppavlov 0.10.0 has requirement ruamel.yaml==0.15.100, but you'll have ruamel-yaml 0.15.87 which is incompatible.
# ERROR: deeppavlov 0.10.0 has requirement scikit-learn==0.21.2, but you'll have scikit-learn 0.23.1 which is incompatible.
# Installing collected packages: retworkx, qiskit-terra, qiskit-aer, websockets, qiskit-ibmq-provider, qiskit-ignis, multitasking, lxml, yfinance, qiskit-aqua, qiskit
#   Attempting uninstall: retworkx
#     Found existing installation: retworkx 0.3.4
#     Uninstalling retworkx-0.3.4:
#       Successfully uninstalled retworkx-0.3.4
#   Attempting uninstall: qiskit-terra
#     Found existing installation: qiskit-terra 0.14.2
#     Uninstalling qiskit-terra-0.14.2:
#       Successfully uninstalled qiskit-terra-0.14.2
#   Attempting uninstall: qiskit-aer
#     Found existing installation: qiskit-aer 0.5.2
#     Uninstalling qiskit-aer-0.5.2:
#       Successfully uninstalled qiskit-aer-0.5.2
#   Attempting uninstall: websockets
#     Found existing installation: websockets 7.0
#     Uninstalling websockets-7.0:
#       Successfully uninstalled websockets-7.0
#   Attempting uninstall: qiskit-ibmq-provider
#     Found existing installation: qiskit-ibmq-provider 0.7.2
#     Uninstalling qiskit-ibmq-provider-0.7.2:
#       Successfully uninstalled qiskit-ibmq-provider-0.7.2
#   Attempting uninstall: qiskit-ignis
#     Found existing installation: qiskit-ignis 0.3.0
#     Uninstalling qiskit-ignis-0.3.0:
#       Successfully uninstalled qiskit-ignis-0.3.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.5.0
#     Uninstalling lxml-4.5.0:
#       Successfully uninstalled lxml-4.5.0
#   Attempting uninstall: qiskit-aqua
#     Found existing installation: qiskit-aqua 0.7.2
#     Uninstalling qiskit-aqua-0.7.2:
#       Successfully uninstalled qiskit-aqua-0.7.2
#   Attempting uninstall: qiskit
#     Found existing installation: qiskit 0.19.4
#     Uninstalling qiskit-0.19.4:
#       Successfully uninstalled qiskit-0.19.4
# Successfully installed lxml-4.5.2 multitasking-0.0.9 qiskit-0.22.0 qiskit-aer-0.6.1 qiskit-aqua-0.7.5 qiskit-ibmq-provider-0.10.0 qiskit-ignis-0.4.0 qiskit-terra-0.15.2 retworkx-0.5.0 websockets-8.1 yfinance-0.1.55

# %%
from qiskit import *
from qiskit.visualization import plot_bloch_vector
# %matplotlib inline

# %%
plot_bloch_vector([0,0,1], title="Spin-Up")

# %%
circuit = QuantumCircuit(1,1)

# %%
# %matplotlib inline
circuit.barrier()
circuit.draw(output='mpl')

# %%
circuit.x(0)
circuit.barrier()
circuit.draw(output='mpl')

# %%
from qiskit import Aer
backend = Aer.get_backend('statevector_simulator')

# %%
job = execute(circuit, backend)

# %%
result = job.result()

# %%
outputstate = result.get_statevector(circuit, decimals=3)

# %%
print(outputstate)
# Out:
# [0.+0.j 1.+0.j]
